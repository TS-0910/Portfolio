# %%
import pandas as pd

# %%
transaction_1 = pd.read_csv("transaction_1.csv")
transaction_1 .head()
# Out:
#   transaction_id   price         payment_date customer_id
# 0    T0000000113  210000  2019-02-01 01:36:57    PL563502
# 1    T0000000114   50000  2019-02-01 01:37:23    HD678019
# 2    T0000000115  120000  2019-02-01 02:34:19    HD298120
# 3    T0000000116  210000  2019-02-01 02:47:23    IK452215
# 4    T0000000117  170000  2019-02-01 04:33:46    PL542865

# %%
transaction_2 = pd.read_csv("transaction_2.csv")
transaction_2.head()
# Out:
#   transaction_id   price         payment_date customer_id
# 0    T0000005113  295000  2019-06-15 07:20:27    TS169261
# 1    T0000005114   50000  2019-06-15 07:35:47    HI599892
# 2    T0000005115   85000  2019-06-15 07:56:36    HI421757
# 3    T0000005116   50000  2019-06-15 08:40:55    OA386378
# 4    T0000005117  120000  2019-06-15 08:44:23    TS506913

# %%
transaction = pd.concat([transaction_1, transaction_2], ignore_index = True)
transaction
# Out:
#      transaction_id   price         payment_date customer_id
# 0       T0000000113  210000  2019-02-01 01:36:57    PL563502
# 1       T0000000114   50000  2019-02-01 01:37:23    HD678019
# 2       T0000000115  120000  2019-02-01 02:34:19    HD298120
# 3       T0000000116  210000  2019-02-01 02:47:23    IK452215
# 4       T0000000117  170000  2019-02-01 04:33:46    PL542865
# ...             ...     ...                  ...         ...
# 6781    T0000006894  180000  2019-07-31 21:20:44    HI400734
# 6782    T0000006895   85000  2019-07-31 21:52:48    AS339451
# 6783    T0000006896  100000  2019-07-31 23:35:25    OA027325
# 6784    T0000006897   85000  2019-07-31 23:39:35    TS624738
# 6785    T0000006898   85000  2019-07-31 23:41:38    AS834214
#
# [6786 rows x 4 columns]

# %%
transaction_detail_1 = pd.read_csv("transaction_detail_1.csv")
transaction_detail_1.head()
# Out:
#    detail_id transaction_id item_id  quantity
# 0          0    T0000000113    S005         1
# 1          1    T0000000114    S001         1
# 2          2    T0000000115    S003         1
# 3          3    T0000000116    S005         1
# 4          4    T0000000117    S002         2

# %%
transaction_detail_2 = pd.read_csv("transaction_detail_2.csv")
transaction_detail_2.head()
# Out:
#    detail_id transaction_id item_id  quantity
# 0       5000    T0000004870    S002         3
# 1       5001    T0000004871    S003         1
# 2       5002    T0000004872    S001         2
# 3       5003    T0000004873    S004         1
# 4       5004    T0000004874    S003         2

# %%
transaction_detail = pd.concat([transaction_detail_1, transaction_detail_2], ignore_index = True)
transaction_detail
# Out:
#       detail_id transaction_id item_id  quantity
# 0             0    T0000000113    S005         1
# 1             1    T0000000114    S001         1
# 2             2    T0000000115    S003         1
# 3             3    T0000000116    S005         1
# 4             4    T0000000117    S002         2
# ...         ...            ...     ...       ...
# 7139       7139    T0000006894    S004         1
# 7140       7140    T0000006895    S002         1
# 7141       7141    T0000006896    S001         2
# 7142       7142    T0000006897    S002         1
# 7143       7143    T0000006898    S002         1
#
# [7144 rows x 4 columns]

# %%
join_data = pd.merge(transaction_detail, transaction, on = "transaction_id", how = "left").drop(columns = "price")
join_data
# Out:
#       detail_id transaction_id item_id  quantity         payment_date  \
# 0             0    T0000000113    S005         1  2019-02-01 01:36:57
# 1             1    T0000000114    S001         1  2019-02-01 01:37:23
# 2             2    T0000000115    S003         1  2019-02-01 02:34:19
# 3             3    T0000000116    S005         1  2019-02-01 02:47:23
# 4             4    T0000000117    S002         2  2019-02-01 04:33:46
# ...         ...            ...     ...       ...                  ...
# 7139       7139    T0000006894    S004         1  2019-07-31 21:20:44
# 7140       7140    T0000006895    S002         1  2019-07-31 21:52:48
# 7141       7141    T0000006896    S001         2  2019-07-31 23:35:25
# 7142       7142    T0000006897    S002         1  2019-07-31 23:39:35
# 7143       7143    T0000006898    S002         1  2019-07-31 23:41:38
#
#      customer_id
# 0       PL563502
# 1       HD678019
# 2       HD298120
# 3       IK452215
# 4       PL542865
# ...

# %%
item_master = pd.read_csv("item_master.csv")
item_master.head()
# Out:
#   item_id item_name  item_price
# 0    S001      PC-A       50000
# 1    S002      PC-B       85000
# 2    S003      PC-C      120000
# 3    S004      PC-D      180000
# 4    S005      PC-E      210000

# %%
customer_master = pd.read_csv("customer_master.csv")
customer_master.head()
# Out:
#   customer_id customer_name    registration_date customer_name_kana  \
# 0    IK152942        平田 裕次郎  2019-01-01 00:25:33          ひらた ゆうじろう
# 1    TS808488         田村 詩織  2019-01-01 01:13:45            たむら しおり
# 2    AS834628         久野 由樹  2019-01-01 02:00:14             ひさの ゆき
# 3    AS345469          鶴岡 薫  2019-01-01 04:48:22           つるおか かおる
# 4    GD892565         大内 高史  2019-01-01 04:54:51           おおうち たかし
#
#                          email gender  age      birth pref
# 0  hirata_yuujirou@example.com      M   29  1990/6/10  石川県
# 1    tamura_shiori@example.com      F   33  1986/5/20  東京都
# 2      hisano_yuki@example.com      F   63   1956/1/2  茨城県
# 3   tsuruoka_kaoru@example.com      M   74  1945/3/25  東京都
# 4   oouchi_takashi@example.com      M   54   1965/8/5  千葉県

# %%
join_data2 = pd.merge(join_data, customer_master, on = "customer_id", how = "left")
join_data2
# Out:
#       detail_id transaction_id item_id  quantity         payment_date  \
# 0             0    T0000000113    S005         1  2019-02-01 01:36:57
# 1             1    T0000000114    S001         1  2019-02-01 01:37:23
# 2             2    T0000000115    S003         1  2019-02-01 02:34:19
# 3             3    T0000000116    S005         1  2019-02-01 02:47:23
# 4             4    T0000000117    S002         2  2019-02-01 04:33:46
# ...         ...            ...     ...       ...                  ...
# 7139       7139    T0000006894    S004         1  2019-07-31 21:20:44
# 7140       7140    T0000006895    S002         1  2019-07-31 21:52:48
# 7141       7141    T0000006896    S001         2  2019-07-31 23:35:25
# 7142       7142    T0000006897    S002         1  2019-07-31 23:39:35
# 7143       7143    T0000006898    S002         1  2019-07-31 23:41:38
#
#      customer_id customer_name    registration_date customer_name_kana  \
# ...

# %%
join_data3 = pd.merge(join_data2, item_master, on = "item_id", how = "left")
join_data3
# Out:
#       detail_id transaction_id item_id  quantity         payment_date  \
# 0             0    T0000000113    S005         1  2019-02-01 01:36:57
# 1             1    T0000000114    S001         1  2019-02-01 01:37:23
# 2             2    T0000000115    S003         1  2019-02-01 02:34:19
# 3             3    T0000000116    S005         1  2019-02-01 02:47:23
# 4             4    T0000000117    S002         2  2019-02-01 04:33:46
# ...         ...            ...     ...       ...                  ...
# 7139       7139    T0000006894    S004         1  2019-07-31 21:20:44
# 7140       7140    T0000006895    S002         1  2019-07-31 21:52:48
# 7141       7141    T0000006896    S001         2  2019-07-31 23:35:25
# 7142       7142    T0000006897    S002         1  2019-07-31 23:39:35
# 7143       7143    T0000006898    S002         1  2019-07-31 23:41:38
#
#      customer_id customer_name    registration_date customer_name_kana  \
# ...

# %%
join_data4 = join_data3.loc[:, ["quantity", "item_price"]]
join_data_price = join_data3["quantity"] * join_data3["item_price"]
join_data4["price"] = join_data_price
join_data4
# Out:
#       quantity  item_price   price
# 0            1      210000  210000
# 1            1       50000   50000
# 2            1      120000  120000
# 3            1      210000  210000
# 4            2       85000  170000
# ...        ...         ...     ...
# 7139         1      180000  180000
# 7140         1       85000   85000
# 7141         2       50000  100000
# 7142         1       85000   85000
# 7143         1       85000   85000
#
# [7144 rows x 3 columns]

# %%
join_data_price.sum()
# Out:
# 971135000

# %%
transaction["price"].sum()
# Out:
# 971135000

# %%
join_data3.isnull().sum()
# Out:
# detail_id             0
# transaction_id        0
# item_id               0
# quantity              0
# payment_date          0
# customer_id           0
# customer_name         0
# registration_date     0
# customer_name_kana    0
# email                 0
# gender                0
# age                   0
# birth                 0
# pref                  0
# item_name             0
# item_price            0
# price                 0
# dtype: int64

# %%
join_data3.describe()
# Out:
#          detail_id     quantity          age     item_price          price
# count  7144.000000  7144.000000  7144.000000    7144.000000    7144.000000
# mean   3571.500000     1.199888    50.265677  121698.628219  135937.150056
# std    2062.439494     0.513647    17.190314   64571.311830   68511.453297
# min       0.000000     1.000000    20.000000   50000.000000   50000.000000
# 25%    1785.750000     1.000000    36.000000   50000.000000   85000.000000
# 50%    3571.500000     1.000000    50.000000  102500.000000  120000.000000
# 75%    5357.250000     1.000000    65.000000  187500.000000  210000.000000
# max    7143.000000     4.000000    80.000000  210000.000000  420000.000000

# %%
join_data3["payment_date"].min()
# Out:
# '2019-02-01 01:36:57'

# %%
join_data3["payment_date"].max()
# Out:
# '2019-07-31 23:41:38'

# %%
join_data5 = join_data3.set_index("payment_date")
join_data5
# Out:
#                      detail_id transaction_id item_id  quantity customer_id  \
# payment_date
# 2019-02-01 01:36:57          0    T0000000113    S005         1    PL563502
# 2019-02-01 01:37:23          1    T0000000114    S001         1    HD678019
# 2019-02-01 02:34:19          2    T0000000115    S003         1    HD298120
# 2019-02-01 02:47:23          3    T0000000116    S005         1    IK452215
# 2019-02-01 04:33:46          4    T0000000117    S002         2    PL542865
# ...                        ...            ...     ...       ...         ...
# 2019-07-31 21:20:44       7139    T0000006894    S004         1    HI400734
# 2019-07-31 21:52:48       7140    T0000006895    S002         1    AS339451
# 2019-07-31 23:35:25       7141    T0000006896    S001         2    OA027325
# 2019-07-31 23:39:35       7142    T0000006897    S002         1    TS624738
# 2019-07-31 23:41:38       7143    T0000006898    S002         1    AS834214
#
# ...

# %%
join_data5.index = pd.to_datetime(join_data5.index)
join_data6 = join_data5.resample("M").sum()
join_data6["price"]
# Out:
# payment_date
# 2019-02-28    160185000
# 2019-03-31    160370000
# 2019-04-30    160510000
# 2019-05-31    155420000
# 2019-06-30    164030000
# 2019-07-31    170620000
# Freq: M, Name: price, dtype: int64
